# %%
import tupak
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# Out:
# 15:59 tupak INFO    : Running tupak version: 0.2.2: (UNCLEAN) 3b48fec 2018-09-02 21:49:04 +1000

# %%
num_events=20
mu_true=50
sig_true=7

# %%
"""
Tutorial to demonstrate running parameter estimation on a reduced parameter space for an injected signal.
This example estimates the masses using a uniform prior in both component masses and distance using a uniform in
comoving volume prior on luminosity distance between luminosity distances of 100Mpc and 5Gpc, the cosmology is WMAP7.
"""
from __future__ import division, print_function
import numpy as np
import tupak
# Set the duration and sampling frequency of the data segment that we're going to inject the signal into
duration = 4.
sampling_frequency = 2048.
# Specify the output directory and the name of the simulation.



for k in range(0,num_events):

    outdir = 'outdir'+str(k)
    label = 'basic_tutorial'+str(k)
    tupak.core.utils.setup_logger(outdir=outdir, label=label)
    # Set up a random seed for result reproducibility.  This is optional!
    np.random.seed(88170235+k)
    # We are going to inject a binary black hole waveform.  We first establish a dictionary of parameters that
    # includes all of the different waveform parameters, including masses of the two black holes (mass_1, mass_2),
    # spins of both black holes (a, tilt, phi), etc.

    m1=np.random.normal(mu_true,sig_true)
    m2=np.random.normal(mu_true,sig_true)
    
    if m2>m1:
        m3=m1
        m1=m2
        m2=m3

    injection_parameters = dict(mass_1=m1, mass_2=m2, a_1=0.4, a_2=0.3, tilt_1=0.5, tilt_2=1.0, phi_12=1.7, phi_jl=0.3,
                                luminosity_distance=1500., iota=0.2, psi=2.659, phase=1.3, geocent_time=1126259642.413,
                                ra=1.375, dec=-1.2108)
    #injection_parameters = dict(mass_1=36., mass_2=29., a_1=0.4, a_2=0.3, tilt_1=0.5, tilt_2=1.0, phi_12=1.7, phi_jl=0.3,
                                #luminosity_distance=1000., iota=0.4, psi=2.659, phase=1.3, geocent_time=1126259642.413,
                                #ra=1.375, dec=-1.2108)
    # Fixed arguments passed into the source model
    waveform_arguments = dict(waveform_approximant='IMRPhenomPv2',
                              reference_frequency=50.)
    # Create the waveform_generator using a LAL BinaryBlackHole source function
    waveform_generator = tupak.gw.WaveformGenerator(
        duration=duration, sampling_frequency=sampling_frequency,
        frequency_domain_source_model=tupak.gw.source.lal_binary_black_hole,
        parameters=injection_parameters, waveform_arguments=waveform_arguments)
    hf_signal = waveform_generator.frequency_domain_strain()
    # Set up interferometers.  In this case we'll use two interferometers
    # (LIGO-Hanford (H1), LIGO-Livingston (L1). These default to their design
    # sensitivity
    IFOs = []
    for name in ["H1", "L1"]:#,"V1"]: ##V1 virgo, ET Einstein Telescope, #K1 Kagra
        IFOs.append(
            tupak.gw.detector.get_interferometer_with_fake_noise_and_injection(
                name, injection_polarizations=hf_signal,
                injection_parameters=injection_parameters, duration=duration,
                sampling_frequency=sampling_frequency, outdir=outdir))
    # Set up prior, which is a dictionary
    # By default we will sample all terms in the signal models.  However, this will take a long time for the calculation,
    # so for this example we will set almost all of the priors to be equall to their injected values.  This implies the
    # prior is a delta function at the true, injected value.  In reality, the sampler implementation is smart enough to
    # not sample any parameter that has a delta-function prior.
    # The above list does *not* include mass_1, mass_2, iota and luminosity_distance, which means those are the parameters
    # that will be included in the sampler.  If we do nothing, then the default priors get used.
    priors = tupak.gw.prior.BBHPriorSet()
    priors['geocent_time'] = tupak.core.prior.Uniform(
        minimum=injection_parameters['geocent_time'] - 1, maximum=injection_parameters['geocent_time'] + 1,
        name='geocent_time', latex_label='$t_c$')
    for key in ['a_1', 'a_2', 'tilt_1', 'tilt_2', 'phi_12', 'phi_jl', 'psi', 'geocent_time', 'phase','ra','dec','iota','luminosity_distance']:
        priors[key] = injection_parameters[key]
    # Initialise the likelihood by passing in the interferometer data (IFOs) and the waveoform generator
    likelihood = tupak.gw.GravitationalWaveTransient(interferometers=IFOs, waveform_generator=waveform_generator,
                                                  time_marginalization=False, phase_marginalization=False,
                                                  distance_marginalization=False, prior=priors)
    # Run sampler.  In this case we're going to use the `dynesty` sampler
    result = tupak.run_sampler(likelihood=likelihood, priors=priors, sampler='dynesty', npoints=1000,dlogz=0.01,resume=True,#,nlive=500,walks=500,dlogz=0.01,resume=True,
                               injection_parameters=injection_parameters, outdir=outdir, label=label)
    # make some plots of the outputs
    result.plot_corner()
# Out:
# 15:59 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 15:59 tupak INFO    : Injected signal in H1:
# 15:59 tupak INFO    :   optimal SNR = 23.93
# 15:59 tupak INFO    :   matched filter SNR = 23.26
# 15:59 tupak INFO    :   mass_1 = 49.73628174841548
# 15:59 tupak INFO    :   mass_2 = 49.06446702703715
# 15:59 tupak INFO    :   a_1 = 0.4
# 15:59 tupak INFO    :   a_2 = 0.3
# 15:59 tupak INFO    :   tilt_1 = 0.5
# 15:59 tupak INFO    :   tilt_2 = 1.0
# 15:59 tupak INFO    :   phi_12 = 1.7
# 15:59 tupak INFO    :   phi_jl = 0.3
# 15:59 tupak INFO    :   luminosity_distance = 1500.0
# 15:59 tupak INFO    :   iota = 0.2
# 15:59 tupak INFO    :   psi = 2.659
# 15:59 tupak INFO    :   phase = 1.3
# 15:59 tupak INFO    :   geocent_time = 1126259642.413
# 15:59 tupak INFO    :   ra = 1.375
# 15:59 tupak INFO    :   dec = -1.2108
# 15:59 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 15:59 tupak INFO    : Injected signal in L1:
# 15:59 tupak INFO    :   optimal SNR = 19.39
# 15:59 tupak INFO    :   matched filter SNR = 19.94
# 15:59 tupak INFO    :   mass_1 = 49.73628174841548
# 15:59 tupak INFO    :   mass_2 = 49.06446702703715
# 15:59 tupak INFO    :   a_1 = 0.4
# 15:59 tupak INFO    :   a_2 = 0.3
# 15:59 tupak INFO    :   tilt_1 = 0.5
# 15:59 tupak INFO    :   tilt_2 = 1.0
# 15:59 tupak INFO    :   phi_12 = 1.7
# 15:59 tupak INFO    :   phi_jl = 0.3
# 15:59 tupak INFO    :   luminosity_distance = 1500.0
# 15:59 tupak INFO    :   iota = 0.2
# 15:59 tupak INFO    :   psi = 2.659
# 15:59 tupak INFO    :   phase = 1.3
# 15:59 tupak INFO    :   geocent_time = 1126259642.413
# 15:59 tupak INFO    :   ra = 1.375
# 15:59 tupak INFO    :   dec = -1.2108
# 15:59 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 15:59 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 15:59 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 15:59 tupak INFO    : Search parameters:
# 15:59 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 15:59 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 15:59 tupak INFO    :   a_1 = 0.4
# 15:59 tupak INFO    :   a_2 = 0.3
# 15:59 tupak INFO    :   tilt_1 = 0.5
# 15:59 tupak INFO    :   tilt_2 = 1.0
# 15:59 tupak INFO    :   phi_12 = 1.7
# 15:59 tupak INFO    :   phi_jl = 0.3
# 15:59 tupak INFO    :   luminosity_distance = 1500.0
# 15:59 tupak INFO    :   dec = -1.2108
# 15:59 tupak INFO    :   ra = 1.375
# 15:59 tupak INFO    :   iota = 0.2
# 15:59 tupak INFO    :   psi = 2.659
# 15:59 tupak INFO    :   phase = 1.3
# 15:59 tupak INFO    :   geocent_time = 1126259642.413
# 15:59 tupak INFO    : Single likelihood evaluation took 4.715e-03 s
# 15:59 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3736| logz ratio=454.767 +/-  0.090 | dlogz:  0.000 >  0.01000016:00 tupak INFO    : Sampling time: 0:01:33.254044
# 16:00 tupak INFO    : Results saved to outdir0/
# 16:00 tupak INFO    : Summary of results:
# nsamples: 3986
# log_noise_evidence: -8444.659
# log_evidence: -7989.892 +/-  0.090
# log_bayes_factor: 454.767 +/-  0.090
# 16:00 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:00 tupak INFO    : Injected signal in H1:
# 16:00 tupak INFO    :   optimal SNR = 25.27
# 16:00 tupak INFO    :   matched filter SNR = 24.50
# 16:00 tupak INFO    :   mass_1 = 56.38187706423597
# 16:00 tupak INFO    :   mass_2 = 49.504250881880026
# 16:00 tupak INFO    :   a_1 = 0.4
# 16:00 tupak INFO    :   a_2 = 0.3
# 16:00 tupak INFO    :   tilt_1 = 0.5
# 16:00 tupak INFO    :   tilt_2 = 1.0
# 16:00 tupak INFO    :   phi_12 = 1.7
# 16:00 tupak INFO    :   phi_jl = 0.3
# 16:00 tupak INFO    :   luminosity_distance = 1500.0
# 16:00 tupak INFO    :   iota = 0.2
# 16:00 tupak INFO    :   psi = 2.659
# 16:00 tupak INFO    :   phase = 1.3
# 16:00 tupak INFO    :   geocent_time = 1126259642.413
# 16:00 tupak INFO    :   ra = 1.375
# 16:00 tupak INFO    :   dec = -1.2108
# 16:00 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:00 tupak INFO    : Injected signal in L1:
# 16:00 tupak INFO    :   optimal SNR = 20.47
# 16:00 tupak INFO    :   matched filter SNR = 21.35
# 16:00 tupak INFO    :   mass_1 = 56.38187706423597
# 16:00 tupak INFO    :   mass_2 = 49.504250881880026
# 16:00 tupak INFO    :   a_1 = 0.4
# 16:00 tupak INFO    :   a_2 = 0.3
# 16:00 tupak INFO    :   tilt_1 = 0.5
# 16:00 tupak INFO    :   tilt_2 = 1.0
# 16:00 tupak INFO    :   phi_12 = 1.7
# 16:00 tupak INFO    :   phi_jl = 0.3
# 16:00 tupak INFO    :   luminosity_distance = 1500.0
# 16:00 tupak INFO    :   iota = 0.2
# 16:00 tupak INFO    :   psi = 2.659
# 16:00 tupak INFO    :   phase = 1.3
# 16:00 tupak INFO    :   geocent_time = 1126259642.413
# 16:00 tupak INFO    :   ra = 1.375
# 16:00 tupak INFO    :   dec = -1.2108
# 16:00 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:00 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:00 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:00 tupak INFO    : Search parameters:
# 16:00 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:00 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:00 tupak INFO    :   a_1 = 0.4
# 16:00 tupak INFO    :   a_2 = 0.3
# 16:00 tupak INFO    :   tilt_1 = 0.5
# 16:00 tupak INFO    :   tilt_2 = 1.0
# 16:00 tupak INFO    :   phi_12 = 1.7
# 16:00 tupak INFO    :   phi_jl = 0.3
# 16:00 tupak INFO    :   luminosity_distance = 1500.0
# 16:00 tupak INFO    :   dec = -1.2108
# 16:00 tupak INFO    :   ra = 1.375
# 16:00 tupak INFO    :   iota = 0.2
# 16:00 tupak INFO    :   psi = 2.659
# 16:00 tupak INFO    :   phase = 1.3
# 16:00 tupak INFO    :   geocent_time = 1126259642.413
# 16:00 tupak INFO    : Single likelihood evaluation took 3.752e-03 s
# 16:00 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 200000}
#  3778| logz ratio=517.748 +/-  0.097 | dlogz:  0.000 >  0.01000016:02 tupak INFO    : Sampling time: 0:01:38.603822
# 16:02 tupak INFO    : Results saved to outdir1/
# 16:02 tupak INFO    : Summary of results:
# nsamples: 4028
# log_noise_evidence: -8519.460
# log_evidence: -8001.712 +/-  0.097
# log_bayes_factor: 517.748 +/-  0.097
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in H1:
# 16:02 tupak INFO    :   optimal SNR = 24.32
# 16:02 tupak INFO    :   matched filter SNR = 24.72
# 16:02 tupak INFO    :   mass_1 = 54.08906856060127
# 16:02 tupak INFO    :   mass_2 = 46.97990084438855
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in L1:
# 16:02 tupak INFO    :   optimal SNR = 19.70
# 16:02 tupak INFO    :   matched filter SNR = 20.36
# 16:02 tupak INFO    :   mass_1 = 54.08906856060127
# 16:02 tupak INFO    :   mass_2 = 46.97990084438855
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:02 tupak INFO    : Search parameters:
# 16:02 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    : Single likelihood evaluation took 6.278e-03 s
# 16:02 tupak WARNING : Using cached result
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in H1:
# 16:02 tupak INFO    :   optimal SNR = 26.95
# 16:02 tupak INFO    :   matched filter SNR = 27.11
# 16:02 tupak INFO    :   mass_1 = 57.544828919016425
# 16:02 tupak INFO    :   mass_2 = 56.84651240065207
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in L1:
# 16:02 tupak INFO    :   optimal SNR = 21.83
# 16:02 tupak INFO    :   matched filter SNR = 22.14
# 16:02 tupak INFO    :   mass_1 = 57.544828919016425
# 16:02 tupak INFO    :   mass_2 = 56.84651240065207
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:02 tupak INFO    : Search parameters:
# 16:02 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    : Single likelihood evaluation took 3.116e-03 s
# 16:02 tupak WARNING : Using cached result
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in H1:
# 16:02 tupak INFO    :   optimal SNR = 25.29
# 16:02 tupak INFO    :   matched filter SNR = 26.07
# 16:02 tupak INFO    :   mass_1 = 55.52659764063005
# 16:02 tupak INFO    :   mass_2 = 50.30353290378315
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in L1:
# 16:02 tupak INFO    :   optimal SNR = 20.48
# 16:02 tupak INFO    :   matched filter SNR = 21.47
# 16:02 tupak INFO    :   mass_1 = 55.52659764063005
# 16:02 tupak INFO    :   mass_2 = 50.30353290378315
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:02 tupak INFO    : Search parameters:
# 16:02 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    : Single likelihood evaluation took 2.916e-03 s
# 16:02 tupak WARNING : Using cached result
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in H1:
# 16:02 tupak INFO    :   optimal SNR = 24.06
# 16:02 tupak INFO    :   matched filter SNR = 23.62
# 16:02 tupak INFO    :   mass_1 = 54.423242637813836
# 16:02 tupak INFO    :   mass_2 = 45.52750288787969
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:02 tupak INFO    : Injected signal in L1:
# 16:02 tupak INFO    :   optimal SNR = 19.49
# 16:02 tupak INFO    :   matched filter SNR = 19.21
# 16:02 tupak INFO    :   mass_1 = 54.423242637813836
# 16:02 tupak INFO    :   mass_2 = 45.52750288787969
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:02 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:02 tupak INFO    : Search parameters:
# 16:02 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:02 tupak INFO    :   a_1 = 0.4
# 16:02 tupak INFO    :   a_2 = 0.3
# 16:02 tupak INFO    :   tilt_1 = 0.5
# 16:02 tupak INFO    :   tilt_2 = 1.0
# 16:02 tupak INFO    :   phi_12 = 1.7
# 16:02 tupak INFO    :   phi_jl = 0.3
# 16:02 tupak INFO    :   luminosity_distance = 1500.0
# 16:02 tupak INFO    :   dec = -1.2108
# 16:02 tupak INFO    :   ra = 1.375
# 16:02 tupak INFO    :   iota = 0.2
# 16:02 tupak INFO    :   psi = 2.659
# 16:02 tupak INFO    :   phase = 1.3
# 16:02 tupak INFO    :   geocent_time = 1126259642.413
# 16:02 tupak INFO    : Single likelihood evaluation took 4.375e-03 s
# 16:02 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3717| logz ratio=438.484 +/-  0.090 | dlogz:  0.000 >  0.01000016:03 tupak INFO    : Sampling time: 0:01:33.761798
# 16:03 tupak INFO    : Results saved to outdir5/
# 16:03 tupak INFO    : Summary of results:
# nsamples: 3967
# log_noise_evidence: -8394.161
# log_evidence: -7955.678 +/-  0.090
# log_bayes_factor: 438.484 +/-  0.090
# 16:03 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:03 tupak INFO    : Injected signal in H1:
# 16:03 tupak INFO    :   optimal SNR = 23.82
# 16:03 tupak INFO    :   matched filter SNR = 24.25
# 16:03 tupak INFO    :   mass_1 = 57.92435561131205
# 16:03 tupak INFO    :   mass_2 = 42.36099295323746
# 16:03 tupak INFO    :   a_1 = 0.4
# 16:03 tupak INFO    :   a_2 = 0.3
# 16:03 tupak INFO    :   tilt_1 = 0.5
# 16:03 tupak INFO    :   tilt_2 = 1.0
# 16:03 tupak INFO    :   phi_12 = 1.7
# 16:03 tupak INFO    :   phi_jl = 0.3
# 16:03 tupak INFO    :   luminosity_distance = 1500.0
# 16:03 tupak INFO    :   iota = 0.2
# 16:03 tupak INFO    :   psi = 2.659
# 16:03 tupak INFO    :   phase = 1.3
# 16:03 tupak INFO    :   geocent_time = 1126259642.413
# 16:03 tupak INFO    :   ra = 1.375
# 16:03 tupak INFO    :   dec = -1.2108
# 16:03 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:03 tupak INFO    : Injected signal in L1:
# 16:03 tupak INFO    :   optimal SNR = 19.30
# 16:03 tupak INFO    :   matched filter SNR = 18.66
# 16:03 tupak INFO    :   mass_1 = 57.92435561131205
# 16:03 tupak INFO    :   mass_2 = 42.36099295323746
# 16:03 tupak INFO    :   a_1 = 0.4
# 16:03 tupak INFO    :   a_2 = 0.3
# 16:03 tupak INFO    :   tilt_1 = 0.5
# 16:03 tupak INFO    :   tilt_2 = 1.0
# 16:03 tupak INFO    :   phi_12 = 1.7
# 16:03 tupak INFO    :   phi_jl = 0.3
# 16:03 tupak INFO    :   luminosity_distance = 1500.0
# 16:03 tupak INFO    :   iota = 0.2
# 16:03 tupak INFO    :   psi = 2.659
# 16:03 tupak INFO    :   phase = 1.3
# 16:03 tupak INFO    :   geocent_time = 1126259642.413
# 16:03 tupak INFO    :   ra = 1.375
# 16:03 tupak INFO    :   dec = -1.2108
# 16:03 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:03 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:03 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:03 tupak INFO    : Search parameters:
# 16:03 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:03 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:03 tupak INFO    :   a_1 = 0.4
# 16:03 tupak INFO    :   a_2 = 0.3
# 16:03 tupak INFO    :   tilt_1 = 0.5
# 16:03 tupak INFO    :   tilt_2 = 1.0
# 16:03 tupak INFO    :   phi_12 = 1.7
# 16:03 tupak INFO    :   phi_jl = 0.3
# 16:03 tupak INFO    :   luminosity_distance = 1500.0
# 16:03 tupak INFO    :   dec = -1.2108
# 16:03 tupak INFO    :   ra = 1.375
# 16:03 tupak INFO    :   iota = 0.2
# 16:03 tupak INFO    :   psi = 2.659
# 16:03 tupak INFO    :   phase = 1.3
# 16:03 tupak INFO    :   geocent_time = 1126259642.413
# 16:03 tupak INFO    : Single likelihood evaluation took 5.353e-03 s
# 16:03 tupak WARNING : Using cached result
# 16:03 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:03 tupak INFO    : Injected signal in H1:
# 16:03 tupak INFO    :   optimal SNR = 22.01
# 16:03 tupak INFO    :   matched filter SNR = 22.11
# 16:03 tupak INFO    :   mass_1 = 46.60301876738131
# 16:03 tupak INFO    :   mass_2 = 42.531862317311706
# 16:03 tupak INFO    :   a_1 = 0.4
# 16:03 tupak INFO    :   a_2 = 0.3
# 16:03 tupak INFO    :   tilt_1 = 0.5
# 16:03 tupak INFO    :   tilt_2 = 1.0
# 16:03 tupak INFO    :   phi_12 = 1.7
# 16:03 tupak INFO    :   phi_jl = 0.3
# 16:03 tupak INFO    :   luminosity_distance = 1500.0
# 16:03 tupak INFO    :   iota = 0.2
# 16:03 tupak INFO    :   psi = 2.659
# 16:03 tupak INFO    :   phase = 1.3
# 16:03 tupak INFO    :   geocent_time = 1126259642.413
# 16:03 tupak INFO    :   ra = 1.375
# 16:03 tupak INFO    :   dec = -1.2108
# 16:03 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:03 tupak INFO    : Injected signal in L1:
# 16:03 tupak INFO    :   optimal SNR = 17.83
# 16:03 tupak INFO    :   matched filter SNR = 17.31
# 16:03 tupak INFO    :   mass_1 = 46.60301876738131
# 16:03 tupak INFO    :   mass_2 = 42.531862317311706
# 16:03 tupak INFO    :   a_1 = 0.4
# 16:03 tupak INFO    :   a_2 = 0.3
# 16:03 tupak INFO    :   tilt_1 = 0.5
# 16:03 tupak INFO    :   tilt_2 = 1.0
# 16:03 tupak INFO    :   phi_12 = 1.7
# 16:03 tupak INFO    :   phi_jl = 0.3
# 16:03 tupak INFO    :   luminosity_distance = 1500.0
# 16:03 tupak INFO    :   iota = 0.2
# 16:03 tupak INFO    :   psi = 2.659
# 16:03 tupak INFO    :   phase = 1.3
# 16:03 tupak INFO    :   geocent_time = 1126259642.413
# 16:03 tupak INFO    :   ra = 1.375
# 16:03 tupak INFO    :   dec = -1.2108
# 16:04 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:04 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:04 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:04 tupak INFO    : Search parameters:
# 16:04 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:04 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:04 tupak INFO    :   a_1 = 0.4
# 16:04 tupak INFO    :   a_2 = 0.3
# 16:04 tupak INFO    :   tilt_1 = 0.5
# 16:04 tupak INFO    :   tilt_2 = 1.0
# 16:04 tupak INFO    :   phi_12 = 1.7
# 16:04 tupak INFO    :   phi_jl = 0.3
# 16:04 tupak INFO    :   luminosity_distance = 1500.0
# 16:04 tupak INFO    :   dec = -1.2108
# 16:04 tupak INFO    :   ra = 1.375
# 16:04 tupak INFO    :   iota = 0.2
# 16:04 tupak INFO    :   psi = 2.659
# 16:04 tupak INFO    :   phase = 1.3
# 16:04 tupak INFO    :   geocent_time = 1126259642.413
# 16:04 tupak INFO    : Single likelihood evaluation took 2.039e-03 s
# 16:04 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 300000}
#  3766| logz ratio=377.458 +/-  0.097 | dlogz:  0.000 >  0.01000016:05 tupak INFO    : Sampling time: 0:01:36.403249
# 16:05 tupak INFO    : Results saved to outdir7/
# 16:05 tupak INFO    : Summary of results:
# nsamples: 4016
# log_noise_evidence: -8374.694
# log_evidence: -7997.236 +/-  0.097
# log_bayes_factor: 377.458 +/-  0.097
# 16:05 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:05 tupak INFO    : Injected signal in H1:
# 16:05 tupak INFO    :   optimal SNR = 23.24
# 16:05 tupak INFO    :   matched filter SNR = 23.07
# 16:05 tupak INFO    :   mass_1 = 52.0176014576424
# 16:05 tupak INFO    :   mass_2 = 43.73310808824191
# 16:05 tupak INFO    :   a_1 = 0.4
# 16:05 tupak INFO    :   a_2 = 0.3
# 16:05 tupak INFO    :   tilt_1 = 0.5
# 16:05 tupak INFO    :   tilt_2 = 1.0
# 16:05 tupak INFO    :   phi_12 = 1.7
# 16:05 tupak INFO    :   phi_jl = 0.3
# 16:05 tupak INFO    :   luminosity_distance = 1500.0
# 16:05 tupak INFO    :   iota = 0.2
# 16:05 tupak INFO    :   psi = 2.659
# 16:05 tupak INFO    :   phase = 1.3
# 16:05 tupak INFO    :   geocent_time = 1126259642.413
# 16:05 tupak INFO    :   ra = 1.375
# 16:05 tupak INFO    :   dec = -1.2108
# 16:05 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:05 tupak INFO    : Injected signal in L1:
# 16:05 tupak INFO    :   optimal SNR = 18.83
# 16:05 tupak INFO    :   matched filter SNR = 19.12
# 16:05 tupak INFO    :   mass_1 = 52.0176014576424
# 16:05 tupak INFO    :   mass_2 = 43.73310808824191
# 16:05 tupak INFO    :   a_1 = 0.4
# 16:05 tupak INFO    :   a_2 = 0.3
# 16:05 tupak INFO    :   tilt_1 = 0.5
# 16:05 tupak INFO    :   tilt_2 = 1.0
# 16:05 tupak INFO    :   phi_12 = 1.7
# 16:05 tupak INFO    :   phi_jl = 0.3
# 16:05 tupak INFO    :   luminosity_distance = 1500.0
# 16:05 tupak INFO    :   iota = 0.2
# 16:05 tupak INFO    :   psi = 2.659
# 16:05 tupak INFO    :   phase = 1.3
# 16:05 tupak INFO    :   geocent_time = 1126259642.413
# 16:05 tupak INFO    :   ra = 1.375
# 16:05 tupak INFO    :   dec = -1.2108
# 16:05 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:05 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:05 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:05 tupak INFO    : Search parameters:
# 16:05 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:05 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:05 tupak INFO    :   a_1 = 0.4
# 16:05 tupak INFO    :   a_2 = 0.3
# 16:05 tupak INFO    :   tilt_1 = 0.5
# 16:05 tupak INFO    :   tilt_2 = 1.0
# 16:05 tupak INFO    :   phi_12 = 1.7
# 16:05 tupak INFO    :   phi_jl = 0.3
# 16:05 tupak INFO    :   luminosity_distance = 1500.0
# 16:05 tupak INFO    :   dec = -1.2108
# 16:05 tupak INFO    :   ra = 1.375
# 16:05 tupak INFO    :   iota = 0.2
# 16:05 tupak INFO    :   psi = 2.659
# 16:05 tupak INFO    :   phase = 1.3
# 16:05 tupak INFO    :   geocent_time = 1126259642.413
# 16:05 tupak INFO    : Single likelihood evaluation took 4.966e-03 s
# 16:05 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3859| logz ratio=439.959 +/-  0.103 | dlogz:  0.000 >  0.01000016:07 tupak INFO    : Sampling time: 0:01:40.343104
# 16:07 tupak INFO    : Results saved to outdir8/
# 16:07 tupak INFO    : Summary of results:
# nsamples: 4109
# log_noise_evidence: -8542.845
# log_evidence: -8102.886 +/-  0.103
# log_bayes_factor: 439.959 +/-  0.103
# 16:07 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:07 tupak INFO    : Injected signal in H1:
# 16:07 tupak INFO    :   optimal SNR = 22.51
# 16:07 tupak INFO    :   matched filter SNR = 22.85
# 16:07 tupak INFO    :   mass_1 = 53.581335729419365
# 16:07 tupak INFO    :   mass_2 = 39.710184253344266
# 16:07 tupak INFO    :   a_1 = 0.4
# 16:07 tupak INFO    :   a_2 = 0.3
# 16:07 tupak INFO    :   tilt_1 = 0.5
# 16:07 tupak INFO    :   tilt_2 = 1.0
# 16:07 tupak INFO    :   phi_12 = 1.7
# 16:07 tupak INFO    :   phi_jl = 0.3
# 16:07 tupak INFO    :   luminosity_distance = 1500.0
# 16:07 tupak INFO    :   iota = 0.2
# 16:07 tupak INFO    :   psi = 2.659
# 16:07 tupak INFO    :   phase = 1.3
# 16:07 tupak INFO    :   geocent_time = 1126259642.413
# 16:07 tupak INFO    :   ra = 1.375
# 16:07 tupak INFO    :   dec = -1.2108
# 16:07 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:07 tupak INFO    : Injected signal in L1:
# 16:07 tupak INFO    :   optimal SNR = 18.24
# 16:07 tupak INFO    :   matched filter SNR = 18.75
# 16:07 tupak INFO    :   mass_1 = 53.581335729419365
# 16:07 tupak INFO    :   mass_2 = 39.710184253344266
# 16:07 tupak INFO    :   a_1 = 0.4
# 16:07 tupak INFO    :   a_2 = 0.3
# 16:07 tupak INFO    :   tilt_1 = 0.5
# 16:07 tupak INFO    :   tilt_2 = 1.0
# 16:07 tupak INFO    :   phi_12 = 1.7
# 16:07 tupak INFO    :   phi_jl = 0.3
# 16:07 tupak INFO    :   luminosity_distance = 1500.0
# 16:07 tupak INFO    :   iota = 0.2
# 16:07 tupak INFO    :   psi = 2.659
# 16:07 tupak INFO    :   phase = 1.3
# 16:07 tupak INFO    :   geocent_time = 1126259642.413
# 16:07 tupak INFO    :   ra = 1.375
# 16:07 tupak INFO    :   dec = -1.2108
# 16:07 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:07 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:07 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:07 tupak INFO    : Search parameters:
# 16:07 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:07 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:07 tupak INFO    :   a_1 = 0.4
# 16:07 tupak INFO    :   a_2 = 0.3
# 16:07 tupak INFO    :   tilt_1 = 0.5
# 16:07 tupak INFO    :   tilt_2 = 1.0
# 16:07 tupak INFO    :   phi_12 = 1.7
# 16:07 tupak INFO    :   phi_jl = 0.3
# 16:07 tupak INFO    :   luminosity_distance = 1500.0
# 16:07 tupak INFO    :   dec = -1.2108
# 16:07 tupak INFO    :   ra = 1.375
# 16:07 tupak INFO    :   iota = 0.2
# 16:07 tupak INFO    :   psi = 2.659
# 16:07 tupak INFO    :   phase = 1.3
# 16:07 tupak INFO    :   geocent_time = 1126259642.413
# 16:07 tupak INFO    : Single likelihood evaluation took 9.280e-03 s
# 16:07 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 60000}
#  3863| logz ratio=444.565 +/-  0.101 | dlogz:  0.000 >  0.01000016:08 tupak INFO    : Sampling time: 0:01:39.725530
# 16:08 tupak INFO    : Results saved to outdir9/
# 16:08 tupak INFO    : Summary of results:
# nsamples: 4113
# log_noise_evidence: -8417.551
# log_evidence: -7972.986 +/-  0.101
# log_bayes_factor: 444.565 +/-  0.101
# 16:08 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:08 tupak INFO    : Injected signal in H1:
# 16:08 tupak INFO    :   optimal SNR = 21.60
# 16:08 tupak INFO    :   matched filter SNR = 21.29
# 16:08 tupak INFO    :   mass_1 = 47.78013273919718
# 16:08 tupak INFO    :   mass_2 = 39.76499601907517
# 16:08 tupak INFO    :   a_1 = 0.4
# 16:08 tupak INFO    :   a_2 = 0.3
# 16:08 tupak INFO    :   tilt_1 = 0.5
# 16:08 tupak INFO    :   tilt_2 = 1.0
# 16:08 tupak INFO    :   phi_12 = 1.7
# 16:08 tupak INFO    :   phi_jl = 0.3
# 16:08 tupak INFO    :   luminosity_distance = 1500.0
# 16:08 tupak INFO    :   iota = 0.2
# 16:08 tupak INFO    :   psi = 2.659
# 16:08 tupak INFO    :   phase = 1.3
# 16:08 tupak INFO    :   geocent_time = 1126259642.413
# 16:08 tupak INFO    :   ra = 1.375
# 16:08 tupak INFO    :   dec = -1.2108
# 16:08 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:08 tupak INFO    : Injected signal in L1:
# 16:08 tupak INFO    :   optimal SNR = 17.50
# 16:08 tupak INFO    :   matched filter SNR = 18.60
# 16:08 tupak INFO    :   mass_1 = 47.78013273919718
# 16:08 tupak INFO    :   mass_2 = 39.76499601907517
# 16:08 tupak INFO    :   a_1 = 0.4
# 16:08 tupak INFO    :   a_2 = 0.3
# 16:08 tupak INFO    :   tilt_1 = 0.5
# 16:08 tupak INFO    :   tilt_2 = 1.0
# 16:08 tupak INFO    :   phi_12 = 1.7
# 16:08 tupak INFO    :   phi_jl = 0.3
# 16:08 tupak INFO    :   luminosity_distance = 1500.0
# 16:08 tupak INFO    :   iota = 0.2
# 16:08 tupak INFO    :   psi = 2.659
# 16:08 tupak INFO    :   phase = 1.3
# 16:08 tupak INFO    :   geocent_time = 1126259642.413
# 16:08 tupak INFO    :   ra = 1.375
# 16:08 tupak INFO    :   dec = -1.2108
# 16:08 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:08 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:08 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:08 tupak INFO    : Search parameters:
# 16:08 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:08 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:08 tupak INFO    :   a_1 = 0.4
# 16:08 tupak INFO    :   a_2 = 0.3
# 16:08 tupak INFO    :   tilt_1 = 0.5
# 16:08 tupak INFO    :   tilt_2 = 1.0
# 16:08 tupak INFO    :   phi_12 = 1.7
# 16:08 tupak INFO    :   phi_jl = 0.3
# 16:08 tupak INFO    :   luminosity_distance = 1500.0
# 16:08 tupak INFO    :   dec = -1.2108
# 16:08 tupak INFO    :   ra = 1.375
# 16:08 tupak INFO    :   iota = 0.2
# 16:08 tupak INFO    :   psi = 2.659
# 16:08 tupak INFO    :   phase = 1.3
# 16:08 tupak INFO    :   geocent_time = 1126259642.413
# 16:08 tupak INFO    : Single likelihood evaluation took 5.891e-03 s
# 16:08 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3836| logz ratio=402.951 +/-  0.100 | dlogz:  0.000 >  0.01000016:10 tupak INFO    : Sampling time: 0:01:17.898755
# 16:10 tupak INFO    : Results saved to outdir10/
# 16:10 tupak INFO    : Summary of results:
# nsamples: 4086
# log_noise_evidence: -8344.281
# log_evidence: -7941.329 +/-  0.100
# log_bayes_factor: 402.951 +/-  0.100
# 16:10 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:10 tupak INFO    : Injected signal in H1:
# 16:10 tupak INFO    :   optimal SNR = 23.74
# 16:10 tupak INFO    :   matched filter SNR = 23.35
# 16:10 tupak INFO    :   mass_1 = 51.5228952254193
# 16:10 tupak INFO    :   mass_2 = 46.39669243776572
# 16:10 tupak INFO    :   a_1 = 0.4
# 16:10 tupak INFO    :   a_2 = 0.3
# 16:10 tupak INFO    :   tilt_1 = 0.5
# 16:10 tupak INFO    :   tilt_2 = 1.0
# 16:10 tupak INFO    :   phi_12 = 1.7
# 16:10 tupak INFO    :   phi_jl = 0.3
# 16:10 tupak INFO    :   luminosity_distance = 1500.0
# 16:10 tupak INFO    :   iota = 0.2
# 16:10 tupak INFO    :   psi = 2.659
# 16:10 tupak INFO    :   phase = 1.3
# 16:10 tupak INFO    :   geocent_time = 1126259642.413
# 16:10 tupak INFO    :   ra = 1.375
# 16:10 tupak INFO    :   dec = -1.2108
# 16:10 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:10 tupak INFO    : Injected signal in L1:
# 16:10 tupak INFO    :   optimal SNR = 19.23
# 16:10 tupak INFO    :   matched filter SNR = 18.34
# 16:10 tupak INFO    :   mass_1 = 51.5228952254193
# 16:10 tupak INFO    :   mass_2 = 46.39669243776572
# 16:10 tupak INFO    :   a_1 = 0.4
# 16:10 tupak INFO    :   a_2 = 0.3
# 16:10 tupak INFO    :   tilt_1 = 0.5
# 16:10 tupak INFO    :   tilt_2 = 1.0
# 16:10 tupak INFO    :   phi_12 = 1.7
# 16:10 tupak INFO    :   phi_jl = 0.3
# 16:10 tupak INFO    :   luminosity_distance = 1500.0
# 16:10 tupak INFO    :   iota = 0.2
# 16:10 tupak INFO    :   psi = 2.659
# 16:10 tupak INFO    :   phase = 1.3
# 16:10 tupak INFO    :   geocent_time = 1126259642.413
# 16:10 tupak INFO    :   ra = 1.375
# 16:10 tupak INFO    :   dec = -1.2108
# 16:10 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:10 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:10 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:10 tupak INFO    : Search parameters:
# 16:10 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:10 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:10 tupak INFO    :   a_1 = 0.4
# 16:10 tupak INFO    :   a_2 = 0.3
# 16:10 tupak INFO    :   tilt_1 = 0.5
# 16:10 tupak INFO    :   tilt_2 = 1.0
# 16:10 tupak INFO    :   phi_12 = 1.7
# 16:10 tupak INFO    :   phi_jl = 0.3
# 16:10 tupak INFO    :   luminosity_distance = 1500.0
# 16:10 tupak INFO    :   dec = -1.2108
# 16:10 tupak INFO    :   ra = 1.375
# 16:10 tupak INFO    :   iota = 0.2
# 16:10 tupak INFO    :   psi = 2.659
# 16:10 tupak INFO    :   phase = 1.3
# 16:10 tupak INFO    :   geocent_time = 1126259642.413
# 16:10 tupak INFO    : Single likelihood evaluation took 2.665e-03 s
# 16:10 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 200000}
#  3760| logz ratio=405.859 +/-  0.091 | dlogz:  0.000 >  0.01000016:11 tupak INFO    : Sampling time: 0:01:14.156516
# 16:11 tupak INFO    : Results saved to outdir11/
# 16:11 tupak INFO    : Summary of results:
# nsamples: 4010
# log_noise_evidence: -8516.226
# log_evidence: -8110.368 +/-  0.091
# log_bayes_factor: 405.859 +/-  0.091
# 16:11 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:11 tupak INFO    : Injected signal in H1:
# 16:11 tupak INFO    :   optimal SNR = 23.79
# 16:11 tupak INFO    :   matched filter SNR = 24.35
# 16:11 tupak INFO    :   mass_1 = 58.2562123717923
# 16:11 tupak INFO    :   mass_2 = 42.06247383952379
# 16:11 tupak INFO    :   a_1 = 0.4
# 16:11 tupak INFO    :   a_2 = 0.3
# 16:11 tupak INFO    :   tilt_1 = 0.5
# 16:11 tupak INFO    :   tilt_2 = 1.0
# 16:11 tupak INFO    :   phi_12 = 1.7
# 16:11 tupak INFO    :   phi_jl = 0.3
# 16:11 tupak INFO    :   luminosity_distance = 1500.0
# 16:11 tupak INFO    :   iota = 0.2
# 16:11 tupak INFO    :   psi = 2.659
# 16:11 tupak INFO    :   phase = 1.3
# 16:11 tupak INFO    :   geocent_time = 1126259642.413
# 16:11 tupak INFO    :   ra = 1.375
# 16:11 tupak INFO    :   dec = -1.2108
# 16:11 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:11 tupak INFO    : Injected signal in L1:
# 16:11 tupak INFO    :   optimal SNR = 19.27
# 16:11 tupak INFO    :   matched filter SNR = 18.96
# 16:11 tupak INFO    :   mass_1 = 58.2562123717923
# 16:11 tupak INFO    :   mass_2 = 42.06247383952379
# 16:11 tupak INFO    :   a_1 = 0.4
# 16:11 tupak INFO    :   a_2 = 0.3
# 16:11 tupak INFO    :   tilt_1 = 0.5
# 16:11 tupak INFO    :   tilt_2 = 1.0
# 16:11 tupak INFO    :   phi_12 = 1.7
# 16:11 tupak INFO    :   phi_jl = 0.3
# 16:11 tupak INFO    :   luminosity_distance = 1500.0
# 16:11 tupak INFO    :   iota = 0.2
# 16:11 tupak INFO    :   psi = 2.659
# 16:11 tupak INFO    :   phase = 1.3
# 16:11 tupak INFO    :   geocent_time = 1126259642.413
# 16:11 tupak INFO    :   ra = 1.375
# 16:11 tupak INFO    :   dec = -1.2108
# 16:11 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:11 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:11 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:11 tupak INFO    : Search parameters:
# 16:11 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:11 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:11 tupak INFO    :   a_1 = 0.4
# 16:11 tupak INFO    :   a_2 = 0.3
# 16:11 tupak INFO    :   tilt_1 = 0.5
# 16:11 tupak INFO    :   tilt_2 = 1.0
# 16:11 tupak INFO    :   phi_12 = 1.7
# 16:11 tupak INFO    :   phi_jl = 0.3
# 16:11 tupak INFO    :   luminosity_distance = 1500.0
# 16:11 tupak INFO    :   dec = -1.2108
# 16:11 tupak INFO    :   ra = 1.375
# 16:11 tupak INFO    :   iota = 0.2
# 16:11 tupak INFO    :   psi = 2.659
# 16:11 tupak INFO    :   phase = 1.3
# 16:11 tupak INFO    :   geocent_time = 1126259642.413
# 16:11 tupak INFO    : Single likelihood evaluation took 5.136e-03 s
# 16:11 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3844| logz ratio=473.839 +/-  0.101 | dlogz:  0.000 >  0.01000016:12 tupak INFO    : Sampling time: 0:01:14.033488
# 16:12 tupak INFO    : Results saved to outdir12/
# 16:12 tupak INFO    : Summary of results:
# nsamples: 4094
# log_noise_evidence: -8522.443
# log_evidence: -8048.604 +/-  0.101
# log_bayes_factor: 473.839 +/-  0.101
# 16:12 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:12 tupak INFO    : Injected signal in H1:
# 16:12 tupak INFO    :   optimal SNR = 21.07
# 16:12 tupak INFO    :   matched filter SNR = 21.39
# 16:12 tupak INFO    :   mass_1 = 46.05520542533322
# 16:12 tupak INFO    :   mass_2 = 38.76136256823905
# 16:12 tupak INFO    :   a_1 = 0.4
# 16:12 tupak INFO    :   a_2 = 0.3
# 16:12 tupak INFO    :   tilt_1 = 0.5
# 16:12 tupak INFO    :   tilt_2 = 1.0
# 16:12 tupak INFO    :   phi_12 = 1.7
# 16:12 tupak INFO    :   phi_jl = 0.3
# 16:12 tupak INFO    :   luminosity_distance = 1500.0
# 16:12 tupak INFO    :   iota = 0.2
# 16:12 tupak INFO    :   psi = 2.659
# 16:12 tupak INFO    :   phase = 1.3
# 16:12 tupak INFO    :   geocent_time = 1126259642.413
# 16:12 tupak INFO    :   ra = 1.375
# 16:12 tupak INFO    :   dec = -1.2108
# 16:12 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:12 tupak INFO    : Injected signal in L1:
# 16:12 tupak INFO    :   optimal SNR = 17.07
# 16:12 tupak INFO    :   matched filter SNR = 17.76
# 16:12 tupak INFO    :   mass_1 = 46.05520542533322
# 16:12 tupak INFO    :   mass_2 = 38.76136256823905
# 16:12 tupak INFO    :   a_1 = 0.4
# 16:12 tupak INFO    :   a_2 = 0.3
# 16:12 tupak INFO    :   tilt_1 = 0.5
# 16:12 tupak INFO    :   tilt_2 = 1.0
# 16:12 tupak INFO    :   phi_12 = 1.7
# 16:12 tupak INFO    :   phi_jl = 0.3
# 16:12 tupak INFO    :   luminosity_distance = 1500.0
# 16:12 tupak INFO    :   iota = 0.2
# 16:12 tupak INFO    :   psi = 2.659
# 16:12 tupak INFO    :   phase = 1.3
# 16:12 tupak INFO    :   geocent_time = 1126259642.413
# 16:12 tupak INFO    :   ra = 1.375
# 16:12 tupak INFO    :   dec = -1.2108
# 16:12 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:12 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:12 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:12 tupak INFO    : Search parameters:
# 16:12 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:12 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:12 tupak INFO    :   a_1 = 0.4
# 16:12 tupak INFO    :   a_2 = 0.3
# 16:12 tupak INFO    :   tilt_1 = 0.5
# 16:12 tupak INFO    :   tilt_2 = 1.0
# 16:12 tupak INFO    :   phi_12 = 1.7
# 16:12 tupak INFO    :   phi_jl = 0.3
# 16:12 tupak INFO    :   luminosity_distance = 1500.0
# 16:12 tupak INFO    :   dec = -1.2108
# 16:12 tupak INFO    :   ra = 1.375
# 16:12 tupak INFO    :   iota = 0.2
# 16:12 tupak INFO    :   psi = 2.659
# 16:12 tupak INFO    :   phase = 1.3
# 16:12 tupak INFO    :   geocent_time = 1126259642.413
# 16:12 tupak INFO    : Single likelihood evaluation took 2.612e-03 s
# 16:12 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 200000}
#  3880| logz ratio=394.810 +/-  0.106 | dlogz:  0.000 >  0.01000016:14 tupak INFO    : Sampling time: 0:01:18.454071
# 16:14 tupak INFO    : Results saved to outdir13/
# 16:14 tupak INFO    : Summary of results:
# nsamples: 4130
# log_noise_evidence: -8318.539
# log_evidence: -7923.729 +/-  0.106
# log_bayes_factor: 394.810 +/-  0.106
# 16:14 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# ...
# 16:15 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:15 tupak INFO    : Search parameters:
# 16:15 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:15 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:15 tupak INFO    :   a_1 = 0.4
# 16:15 tupak INFO    :   a_2 = 0.3
# 16:15 tupak INFO    :   tilt_1 = 0.5
# 16:15 tupak INFO    :   tilt_2 = 1.0
# 16:15 tupak INFO    :   phi_12 = 1.7
# 16:15 tupak INFO    :   phi_jl = 0.3
# 16:15 tupak INFO    :   luminosity_distance = 1500.0
# 16:15 tupak INFO    :   dec = -1.2108
# 16:15 tupak INFO    :   ra = 1.375
# 16:15 tupak INFO    :   iota = 0.2
# 16:15 tupak INFO    :   psi = 2.659
# 16:15 tupak INFO    :   phase = 1.3
# 16:15 tupak INFO    :   geocent_time = 1126259642.413
# 16:15 tupak INFO    : Single likelihood evaluation took 4.104e-03 s
# 16:15 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 100000}
#  3796| logz ratio=516.834 +/-  0.096 | dlogz:  0.000 >  0.01000016:16 tupak INFO    : Sampling time: 0:01:12.955473
# 16:16 tupak INFO    : Results saved to outdir15/
# 16:16 tupak INFO    : Summary of results:
# nsamples: 4046
# log_noise_evidence: -8480.779
# log_evidence: -7963.944 +/-  0.096
# log_bayes_factor: 516.834 +/-  0.096
# 16:16 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:16 tupak INFO    : Injected signal in H1:
# 16:16 tupak INFO    :   optimal SNR = 24.29
# 16:16 tupak INFO    :   matched filter SNR = 23.60
# 16:16 tupak INFO    :   mass_1 = 55.988613617817975
# 16:16 tupak INFO    :   mass_2 = 45.453471574387194
# 16:16 tupak INFO    :   a_1 = 0.4
# 16:16 tupak INFO    :   a_2 = 0.3
# 16:16 tupak INFO    :   tilt_1 = 0.5
# 16:16 tupak INFO    :   tilt_2 = 1.0
# 16:16 tupak INFO    :   phi_12 = 1.7
# 16:16 tupak INFO    :   phi_jl = 0.3
# 16:16 tupak INFO    :   luminosity_distance = 1500.0
# 16:16 tupak INFO    :   iota = 0.2
# 16:16 tupak INFO    :   psi = 2.659
# 16:16 tupak INFO    :   phase = 1.3
# 16:16 tupak INFO    :   geocent_time = 1126259642.413
# 16:16 tupak INFO    :   ra = 1.375
# 16:16 tupak INFO    :   dec = -1.2108
# 16:16 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:16 tupak INFO    : Injected signal in L1:
# 16:16 tupak INFO    :   optimal SNR = 19.68
# 16:16 tupak INFO    :   matched filter SNR = 18.46
# 16:16 tupak INFO    :   mass_1 = 55.988613617817975
# 16:16 tupak INFO    :   mass_2 = 45.453471574387194
# 16:16 tupak INFO    :   a_1 = 0.4
# 16:16 tupak INFO    :   a_2 = 0.3
# 16:16 tupak INFO    :   tilt_1 = 0.5
# 16:16 tupak INFO    :   tilt_2 = 1.0
# 16:16 tupak INFO    :   phi_12 = 1.7
# 16:16 tupak INFO    :   phi_jl = 0.3
# 16:16 tupak INFO    :   luminosity_distance = 1500.0
# 16:16 tupak INFO    :   iota = 0.2
# 16:16 tupak INFO    :   psi = 2.659
# 16:16 tupak INFO    :   phase = 1.3
# 16:16 tupak INFO    :   geocent_time = 1126259642.413
# 16:16 tupak INFO    :   ra = 1.375
# 16:16 tupak INFO    :   dec = -1.2108
# 16:16 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:16 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:16 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:16 tupak INFO    : Search parameters:
# 16:16 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:16 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:16 tupak INFO    :   a_1 = 0.4
# 16:16 tupak INFO    :   a_2 = 0.3
# 16:16 tupak INFO    :   tilt_1 = 0.5
# 16:16 tupak INFO    :   tilt_2 = 1.0
# 16:16 tupak INFO    :   phi_12 = 1.7
# 16:16 tupak INFO    :   phi_jl = 0.3
# 16:16 tupak INFO    :   luminosity_distance = 1500.0
# 16:16 tupak INFO    :   dec = -1.2108
# 16:16 tupak INFO    :   ra = 1.375
# 16:16 tupak INFO    :   iota = 0.2
# 16:16 tupak INFO    :   psi = 2.659
# 16:16 tupak INFO    :   phase = 1.3
# 16:16 tupak INFO    :   geocent_time = 1126259642.413
# 16:16 tupak INFO    : Single likelihood evaluation took 2.756e-03 s
# 16:16 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 200000}
#  3839| logz ratio=401.129 +/-  0.099 | dlogz:  0.000 >  0.01000016:17 tupak INFO    : Sampling time: 0:01:14.962851
# 16:17 tupak INFO    : Results saved to outdir16/
# 16:17 tupak INFO    : Summary of results:
# nsamples: 4089
# log_noise_evidence: -8483.952
# log_evidence: -8082.823 +/-  0.099
# log_bayes_factor: 401.129 +/-  0.099
# 16:17 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:17 tupak INFO    : Injected signal in H1:
# 16:17 tupak INFO    :   optimal SNR = 21.26
# 16:17 tupak INFO    :   matched filter SNR = 21.79
# 16:17 tupak INFO    :   mass_1 = 42.73923886072897
# 16:17 tupak INFO    :   mass_2 = 42.6501037601342
# 16:17 tupak INFO    :   a_1 = 0.4
# 16:17 tupak INFO    :   a_2 = 0.3
# 16:17 tupak INFO    :   tilt_1 = 0.5
# 16:17 tupak INFO    :   tilt_2 = 1.0
# 16:17 tupak INFO    :   phi_12 = 1.7
# 16:17 tupak INFO    :   phi_jl = 0.3
# 16:17 tupak INFO    :   luminosity_distance = 1500.0
# 16:17 tupak INFO    :   iota = 0.2
# 16:17 tupak INFO    :   psi = 2.659
# 16:17 tupak INFO    :   phase = 1.3
# 16:17 tupak INFO    :   geocent_time = 1126259642.413
# 16:17 tupak INFO    :   ra = 1.375
# 16:17 tupak INFO    :   dec = -1.2108
# 16:17 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:17 tupak INFO    : Injected signal in L1:
# 16:17 tupak INFO    :   optimal SNR = 17.22
# 16:17 tupak INFO    :   matched filter SNR = 17.29
# 16:17 tupak INFO    :   mass_1 = 42.73923886072897
# 16:17 tupak INFO    :   mass_2 = 42.6501037601342
# 16:17 tupak INFO    :   a_1 = 0.4
# 16:17 tupak INFO    :   a_2 = 0.3
# 16:17 tupak INFO    :   tilt_1 = 0.5
# 16:17 tupak INFO    :   tilt_2 = 1.0
# 16:17 tupak INFO    :   phi_12 = 1.7
# 16:17 tupak INFO    :   phi_jl = 0.3
# 16:17 tupak INFO    :   luminosity_distance = 1500.0
# 16:17 tupak INFO    :   iota = 0.2
# 16:17 tupak INFO    :   psi = 2.659
# 16:17 tupak INFO    :   phase = 1.3
# 16:17 tupak INFO    :   geocent_time = 1126259642.413
# 16:17 tupak INFO    :   ra = 1.375
# 16:17 tupak INFO    :   dec = -1.2108
# 16:17 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:17 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:17 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:17 tupak INFO    : Search parameters:
# 16:17 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:17 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:17 tupak INFO    :   a_1 = 0.4
# 16:17 tupak INFO    :   a_2 = 0.3
# 16:17 tupak INFO    :   tilt_1 = 0.5
# 16:17 tupak INFO    :   tilt_2 = 1.0
# 16:17 tupak INFO    :   phi_12 = 1.7
# 16:17 tupak INFO    :   phi_jl = 0.3
# 16:17 tupak INFO    :   luminosity_distance = 1500.0
# 16:17 tupak INFO    :   dec = -1.2108
# 16:17 tupak INFO    :   ra = 1.375
# 16:17 tupak INFO    :   iota = 0.2
# 16:17 tupak INFO    :   psi = 2.659
# 16:17 tupak INFO    :   phase = 1.3
# 16:17 tupak INFO    :   geocent_time = 1126259642.413
# 16:17 tupak INFO    : Single likelihood evaluation took 2.698e-03 s
# 16:17 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 200000}
#  3885| logz ratio=388.942 +/-  0.109 | dlogz:  0.000 >  0.01000016:19 tupak INFO    : Sampling time: 0:01:14.439948
# 16:19 tupak INFO    : Results saved to outdir17/
# 16:19 tupak INFO    : Summary of results:
# nsamples: 4135
# log_noise_evidence: -8410.684
# log_evidence: -8021.742 +/-  0.109
# log_bayes_factor: 388.942 +/-  0.109
# 16:19 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:19 tupak INFO    : Injected signal in H1:
# 16:19 tupak INFO    :   optimal SNR = 26.47
# 16:19 tupak INFO    :   matched filter SNR = 26.87
# 16:19 tupak INFO    :   mass_1 = 61.65531417786325
# 16:19 tupak INFO    :   mass_2 = 50.948060431480094
# 16:19 tupak INFO    :   a_1 = 0.4
# 16:19 tupak INFO    :   a_2 = 0.3
# 16:19 tupak INFO    :   tilt_1 = 0.5
# 16:19 tupak INFO    :   tilt_2 = 1.0
# 16:19 tupak INFO    :   phi_12 = 1.7
# 16:19 tupak INFO    :   phi_jl = 0.3
# 16:19 tupak INFO    :   luminosity_distance = 1500.0
# 16:19 tupak INFO    :   iota = 0.2
# 16:19 tupak INFO    :   psi = 2.659
# 16:19 tupak INFO    :   phase = 1.3
# 16:19 tupak INFO    :   geocent_time = 1126259642.413
# 16:19 tupak INFO    :   ra = 1.375
# 16:19 tupak INFO    :   dec = -1.2108
# 16:19 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:19 tupak INFO    : Injected signal in L1:
# 16:19 tupak INFO    :   optimal SNR = 21.44
# 16:19 tupak INFO    :   matched filter SNR = 20.93
# 16:19 tupak INFO    :   mass_1 = 61.65531417786325
# 16:19 tupak INFO    :   mass_2 = 50.948060431480094
# 16:19 tupak INFO    :   a_1 = 0.4
# 16:19 tupak INFO    :   a_2 = 0.3
# 16:19 tupak INFO    :   tilt_1 = 0.5
# 16:19 tupak INFO    :   tilt_2 = 1.0
# 16:19 tupak INFO    :   phi_12 = 1.7
# 16:19 tupak INFO    :   phi_jl = 0.3
# 16:19 tupak INFO    :   luminosity_distance = 1500.0
# 16:19 tupak INFO    :   iota = 0.2
# 16:19 tupak INFO    :   psi = 2.659
# 16:19 tupak INFO    :   phase = 1.3
# 16:19 tupak INFO    :   geocent_time = 1126259642.413
# 16:19 tupak INFO    :   ra = 1.375
# 16:19 tupak INFO    :   dec = -1.2108
# 16:19 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:19 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:19 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:19 tupak INFO    : Search parameters:
# 16:19 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:19 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:19 tupak INFO    :   a_1 = 0.4
# 16:19 tupak INFO    :   a_2 = 0.3
# 16:19 tupak INFO    :   tilt_1 = 0.5
# 16:19 tupak INFO    :   tilt_2 = 1.0
# 16:19 tupak INFO    :   phi_12 = 1.7
# 16:19 tupak INFO    :   phi_jl = 0.3
# 16:19 tupak INFO    :   luminosity_distance = 1500.0
# 16:19 tupak INFO    :   dec = -1.2108
# 16:19 tupak INFO    :   ra = 1.375
# 16:19 tupak INFO    :   iota = 0.2
# 16:19 tupak INFO    :   psi = 2.659
# 16:19 tupak INFO    :   phase = 1.3
# 16:19 tupak INFO    :   geocent_time = 1126259642.413
# 16:19 tupak INFO    : Single likelihood evaluation took 1.659e-03 s
# 16:19 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 400000}
#  3754| logz ratio=570.240 +/-  0.094 | dlogz:  0.000 >  0.01000016:20 tupak INFO    : Sampling time: 0:01:09.812509
# 16:20 tupak INFO    : Results saved to outdir18/
# 16:20 tupak INFO    : Summary of results:
# nsamples: 4004
# log_noise_evidence: -8736.118
# log_evidence: -8165.879 +/-  0.094
# log_bayes_factor: 570.240 +/-  0.094
# 16:20 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:20 tupak INFO    : Injected signal in H1:
# 16:20 tupak INFO    :   optimal SNR = 26.03
# 16:20 tupak INFO    :   matched filter SNR = 26.59
# 16:20 tupak INFO    :   mass_1 = 57.389962003385385
# 16:20 tupak INFO    :   mass_2 = 52.26255805195562
# 16:20 tupak INFO    :   a_1 = 0.4
# 16:20 tupak INFO    :   a_2 = 0.3
# 16:20 tupak INFO    :   tilt_1 = 0.5
# 16:20 tupak INFO    :   tilt_2 = 1.0
# 16:20 tupak INFO    :   phi_12 = 1.7
# 16:20 tupak INFO    :   phi_jl = 0.3
# 16:20 tupak INFO    :   luminosity_distance = 1500.0
# 16:20 tupak INFO    :   iota = 0.2
# 16:20 tupak INFO    :   psi = 2.659
# 16:20 tupak INFO    :   phase = 1.3
# 16:20 tupak INFO    :   geocent_time = 1126259642.413
# 16:20 tupak INFO    :   ra = 1.375
# 16:20 tupak INFO    :   dec = -1.2108
# 16:20 tupak INFO    : No power spectral density provided, using aLIGO,zero detuning, high power.
# 16:20 tupak INFO    : Injected signal in L1:
# 16:20 tupak INFO    :   optimal SNR = 21.08
# 16:20 tupak INFO    :   matched filter SNR = 20.35
# 16:20 tupak INFO    :   mass_1 = 57.389962003385385
# 16:20 tupak INFO    :   mass_2 = 52.26255805195562
# 16:20 tupak INFO    :   a_1 = 0.4
# 16:20 tupak INFO    :   a_2 = 0.3
# 16:20 tupak INFO    :   tilt_1 = 0.5
# 16:20 tupak INFO    :   tilt_2 = 1.0
# 16:20 tupak INFO    :   phi_12 = 1.7
# 16:20 tupak INFO    :   phi_jl = 0.3
# 16:20 tupak INFO    :   luminosity_distance = 1500.0
# 16:20 tupak INFO    :   iota = 0.2
# 16:20 tupak INFO    :   psi = 2.659
# 16:20 tupak INFO    :   phase = 1.3
# 16:20 tupak INFO    :   geocent_time = 1126259642.413
# 16:20 tupak INFO    :   ra = 1.375
# 16:20 tupak INFO    :   dec = -1.2108
# 16:20 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:20 tupak INFO    : No prior given, using default BBH priors in /home/brandon/.conda/envs/pycbc/lib/python3.6/site-packages/tupak/gw/prior_files/binary_black_holes.prior.
# 16:20 tupak WARNING : The waveform_generator start_time is not equal to that of the provided interferometers. Overwriting the waveform_generator.
# 16:20 tupak INFO    : Search parameters:
# 16:20 tupak INFO    :   mass_1 = Uniform(name='mass_1', latex_label='$m_1$', minimum=5, maximum=100)
# 16:20 tupak INFO    :   mass_2 = Uniform(name='mass_2', latex_label='$m_2$', minimum=5, maximum=100)
# 16:20 tupak INFO    :   a_1 = 0.4
# 16:20 tupak INFO    :   a_2 = 0.3
# 16:20 tupak INFO    :   tilt_1 = 0.5
# 16:20 tupak INFO    :   tilt_2 = 1.0
# 16:20 tupak INFO    :   phi_12 = 1.7
# 16:20 tupak INFO    :   phi_jl = 0.3
# 16:20 tupak INFO    :   luminosity_distance = 1500.0
# 16:20 tupak INFO    :   dec = -1.2108
# 16:20 tupak INFO    :   ra = 1.375
# 16:20 tupak INFO    :   iota = 0.2
# 16:20 tupak INFO    :   psi = 2.659
# 16:20 tupak INFO    :   phase = 1.3
# 16:20 tupak INFO    :   geocent_time = 1126259642.413
# 16:20 tupak INFO    : Single likelihood evaluation took 2.047e-03 s
# 16:20 tupak INFO    : Using sampler Dynesty with kwargs {'dlogz': 0.01, 'bound': 'multi', 'sample': 'rwalk', 'resume': True, 'walks': 10, 'verbose': True, 'check_point_delta_t': 600, 'nlive': 250, 'npoints': 1000, 'update_interval': 150, 'n_check_point': 300000}
#  3721| logz ratio=550.628 +/-  0.091 | dlogz:  0.000 >  0.01000016:21 tupak INFO    : Sampling time: 0:01:09.399225
# 16:21 tupak INFO    : Results saved to outdir19/
# 16:21 tupak INFO    : Summary of results:
# nsamples: 3971
# log_noise_evidence: -8433.895
# log_evidence: -7883.267 +/-  0.091
# log_bayes_factor: 550.628 +/-  0.091

# %%
np.save('BHPutil',np.array([num_events,mu_true,sig_true]))

print(result)
#result.plot_corner()
# Out:
# nsamples: 3971
# log_noise_evidence: -8433.895
# log_evidence: -7883.267 +/-  0.091
# log_bayes_factor: 550.628 +/-  0.091

# %%
plt.plot(np.power(hf_signal['plus'],2.0)+np.power(hf_signal['cross'],2.0))

# %%
IFOs[0].plot_data()

# %%
tupak.gw.detector.get_interferometer_with_fake_noise_and_injection
# Out:
# <function tupak.gw.detector.get_interferometer_with_fake_noise_and_injection(name, injection_parameters, injection_polarizations=None, waveform_generator=None, sampling_frequency=4096, duration=4, start_time=None, outdir='outdir', label=None, plot=True, save=True, zero_noise=False)>
